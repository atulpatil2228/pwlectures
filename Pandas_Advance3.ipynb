# %% [markdown]
# <a href="https://colab.research.google.com/github/atulpatil2228/pwlectures/blob/main/Pandas_Advance3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
import pandas as pd
import numpy as np

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1 = df[["Name","Sex","Age"]][0:5]

# %%
df1
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df2 = df[["Name","Sex","Age"]][5:10]

# %%
df2
# Out:
#                                                 Name     Sex   Age
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
"Pw" + "skills"
# Out:
# 'Pwskills'

# %%
df1
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df2
# Out:
#                                                 Name     Sex   Age
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df1,df2],axis = 0) ## concatenate pandas along a  particular axis
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df1,df2],axis = 1)
# Out:
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                                NaN     NaN   NaN
# 6                                                NaN     NaN   NaN
# 7                                                NaN     NaN   NaN
# 8                                                NaN     NaN   NaN
# 9                                                NaN     NaN   NaN
#
#                                                 Name     Sex   Age
# 0                                                NaN     NaN   NaN
# 1                                                NaN     NaN   NaN
# ...

# %%
df2.reset_index(drop = True,inplace  = True)

# %%
pd.concat([df1,df2],axis = 1)
# Out:
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#                                                 Name     Sex   Age
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                     Palsson, Master. Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
### merge

# %%
df1 = pd.DataFrame  ({'key1': [1,2, 4, 5,6],
    'key2': [4, 5, 6, 7,8],
    'key3': [ 3, 4, 5,6,6]})

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2 = pd.DataFrame  ({'key1': [1,2, 45, 6,67],
    'key4': [56, 5, 6, 7,8],
    'key5': [ 3, 56, 5,6,6]})

# %%
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(df1,df2,how = "inner")
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6

# %%
pd.merge(df1,df2,how = "left")
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6   7.0   6.0

# %%
pd.merge(df1,df2,how = "right")
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0    56     3
# 1     2   5.0   4.0     5    56
# 2    45   NaN   NaN     6     5
# 3     6   8.0   6.0     7     6
# 4    67   NaN   NaN     8     6

# %%
pd.merge(df1,df2,how = "outer")## all the keys from both the data frame
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  56.0   3.0
# 1     2   5.0   4.0   5.0  56.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
pd.merge(df1,df2,how = "cross")
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1    56     3
# 1        1     4     3       2     5    56
# 2        1     4     3      45     6     5
# 3        1     4     3       6     7     6
# 4        1     4     3      67     8     6
# 5        2     5     4       1    56     3
# 6        2     5     4       2     5    56
# 7        2     5     4      45     6     5
# 8        2     5     4       6     7     6
# 9        2     5     4      67     8     6
# 10       4     6     5       1    56     3
# 11       4     6     5       2     5    56
# 12       4     6     5      45     6     5
# 13       4     6     5       6     7     6
# 14       4     6     5      67     8     6
# 15       5     7     6       1    56     3
# 16       5     7     6       2     5    56
# 17       5     7     6      45     6     5
# 18       5     7     6       6     7     6
# 19       5     7     6      67     8     6
# 20       6     8     6       1    56     3
# ...

# %%
pd.merge(df1,df2,how = "left",left_on= "key2",right_on="key4")
# Out:
#    key1_x  key2  key3  key1_y  key4  key5
# 0       1     4     3     NaN   NaN   NaN
# 1       2     5     4     2.0   5.0  56.0
# 2       4     6     5    45.0   6.0   5.0
# 3       5     7     6     6.0   7.0   6.0
# 4       6     8     6    67.0   8.0   6.0

# %%
## join

# %%
#join
df1 = pd.DataFrame({'key1':[1,2,4,5,6],
                      'key2':[4,5,6,7,8],
                      'key3':[3,4,5,6,6]},
                    index = ['a', 'b', 'c', 'd', 'e']
)

# %%
df2 =  pd.DataFrame({'key6':[1,2,45,6,67],
                      'key4':[56,5,6,7,8],
                      'key5':[3,56,5,6,6]
},
index = ['a', 'b', 'h', 'i', 'j']
)

# %%
df1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
df2
# Out:
#    key6  key4  key5
# a     1    56     3
# b     2     5    56
# h    45     6     5
# i     6     7     6
# j    67     8     6

# %%
df1.join(df2 ,how = "inner")## Join columns of another DataFrame.
# Out:
#    key1  key2  key3  key6  key4  key5
# a     1     4     3     1    56     3
# b     2     5     4     2     5    56

# %%
df1.join(df2 ,how = "left")
# Out:
#    key1  key2  key3  key6  key4  key5
# a     1     4     3   1.0  56.0   3.0
# b     2     5     4   2.0   5.0  56.0
# c     4     6     5   NaN   NaN   NaN
# d     5     7     6   NaN   NaN   NaN
# e     6     8     6   NaN   NaN   NaN

# %%
df1.join(df2 ,how = "right")
# Out:
#    key1  key2  key3  key6  key4  key5
# a   1.0   4.0   3.0     1    56     3
# b   2.0   5.0   4.0     2     5    56
# h   NaN   NaN   NaN    45     6     5
# i   NaN   NaN   NaN     6     7     6
# j   NaN   NaN   NaN    67     8     6

# %%
df1.join(df2 ,how = "outer")
# Out:
#    key1  key2  key3  key6  key4  key5
# a   1.0   4.0   3.0   1.0  56.0   3.0
# b   2.0   5.0   4.0   2.0   5.0  56.0
# c   4.0   6.0   5.0   NaN   NaN   NaN
# d   5.0   7.0   6.0   NaN   NaN   NaN
# e   6.0   8.0   6.0   NaN   NaN   NaN
# h   NaN   NaN   NaN  45.0   6.0   5.0
# i   NaN   NaN   NaN   6.0   7.0   6.0
# j   NaN   NaN   NaN  67.0   8.0   6.0

# %%
df1.join(df2 ,how = "cross")
# Out:
#     key1  key2  key3  key6  key4  key5
# 0      1     4     3     1    56     3
# 1      1     4     3     2     5    56
# 2      1     4     3    45     6     5
# 3      1     4     3     6     7     6
# 4      1     4     3    67     8     6
# 5      2     5     4     1    56     3
# 6      2     5     4     2     5    56
# 7      2     5     4    45     6     5
# 8      2     5     4     6     7     6
# 9      2     5     4    67     8     6
# 10     4     6     5     1    56     3
# 11     4     6     5     2     5    56
# 12     4     6     5    45     6     5
# 13     4     6     5     6     7     6
# 14     4     6     5    67     8     6
# 15     5     7     6     1    56     3
# 16     5     7     6     2     5    56
# 17     5     7     6    45     6     5
# 18     5     7     6     6     7     6
# 19     5     7     6    67     8     6
# 20     6     8     6     1    56     3
# 21     6     8     6     2     5    56
# 22     6     8     6    45     6     5
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Fare
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df["Fare_inr"] = df['Fare'].apply(lambda x : x*90)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Fare_inr"]
# Out:
# 0       652.500
# 1      6415.497
# 2       713.250
# 3      4779.000
# 4       724.500
#          ...
# 886    1170.000
# 887    2700.000
# 888    2110.500
# 889    2700.000
# 890     697.500
# Name: Fare_inr, Length: 891, dtype: float64

# %%
len('Atul')
# Out:
# 4

# %%
df["Name_len"] = df['Name'].apply(len)

# %%
df["Name_len"]
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name_len, Length: 891, dtype: int64

# %%
def conver(x):
  return x*90

# %%
df["Fare1"] =  df['Fare'].apply(conver)

# %%
df["Fare1"]
# Out:
# 0       652.500
# 1      6415.497
# 2       713.250
# 3      4779.000
# 4       724.500
#          ...
# 886    1170.000
# 887    2700.000
# 888    2110.500
# 889    2700.000
# 890     697.500
# Name: Fare1, Length: 891, dtype: float64

# %%
def create_falg(x):
  if x<10:
    return "Cheap"
  elif x>=10 and x<20:
    return "Medium"
  else:
    return"High"

# %%
df["Flag_fare"] = df["Fare"].apply(create_falg)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = {"a": [1, 2, 3, 4],
       "b": [5, 5, 6, 7],
       "c": ["pw", "skills", "aj", "cj"]}
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#    a  b       c
# 0  1  5      pw
# 1  2  5  skills
# 2  3  6      aj
# 3  4  7      cj

# %%
df1.set_index('c',inplace=True)

# %%
df1
# Out:
#         a  b
# c
# pw      1  5
# skills  2  5
# aj      3  6
# cj      4  7

# %%
df1.reset_index(inplace = True)

# %%
df1
# Out:
#         c  a  b
# 0      pw  1  5
# 1  skills  2  5
# 2      aj  3  6
# 3      cj  4  7

# %%
df1.reset_index(drop = True ,inplace = True)

# %%
df1
# Out:
#    a  b
# 0  1  5
# 1  2  5
# 2  3  6
# 3  4  7

# %%
df1.reindex([1,2,3,0])## conformm Series / data frame to new index with optional logic
# Out:
#    a  b
# 1  2  5
# 2  3  6
# 3  4  7
# 0  1  5

# %%
df1
# Out:
#    a  b
# 0  1  5
# 1  2  5
# 2  3  6
# 3  4  7

# %%
for i in df1.iterrows(): ## row wise
  print(i,"            ")
# Out:
# (0, a    1
# b    5
# Name: 0, dtype: int64)
# (1, a    2
# b    5
# Name: 1, dtype: int64)
# (2, a    3
# b    6
# Name: 2, dtype: int64)
# (3, a    4
# b    7
# Name: 3, dtype: int64)

# %%
for i in df1.items():
  print(i)##  column wise
# Out:
# ('a', 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64)
# ('b', 0    5
# 1    5
# 2    6
# 3    7
# Name: b, dtype: int64)

# %%
def func_sum(x):
  return x.sum()

# %%
df1.apply(func_sum,axis=0)
# Out:
# a    10
# b    23
# dtype: int64

# %%
df1
# Out:
#    a  b
# 0  1  5
# 1  2  5
# 2  3  6
# 3  4  7

# %%
df1.apply(func_sum,axis=1)
# Out:
# 0     6
# 1     7
# 2     9
# 3    11
# dtype: int64

# %%
df1.applymap(lambda x : x**2)
# Out:
# <ipython-input-101-4164dc4901da>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df1.applymap(lambda x : x**2)
#     a   b
# 0   1  25
# 1   4  25
# 2   9  36
# 3  16  49

# %%
df1.sort_values(by = 'a')
# Out:
#    a  b
# 0  1  5
# 1  2  5
# 2  3  6
# 3  4  7

# %%
data = {"a": [100, 200, 13, 4],
       "b": [5, 5, 6, 7],
       "c": ["pw", "skills", "aj", "cj"]}
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#      a  b       c
# 0  100  5      pw
# 1  200  5  skills
# 2   13  6      aj
# 3    4  7      cj

# %%
df2.sort_values(by = 'a')
# Out:
#      a  b       c
# 3    4  7      cj
# 2   13  6      aj
# 0  100  5      pw
# 1  200  5  skills

# %%
df.sort_values(by = "Fare")
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 815          816         0       1                    Fry, Mr. Richard
# 806          807         0       1              Andrews, Mr. Thomas Jr
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 481          482         0       2    Frost, Mr. Anthony Wood "Archie"
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# ...
