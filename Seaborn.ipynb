# %% [markdown]
# <a href="https://colab.research.google.com/github/atulpatil2228/pwlectures/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as  pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## seaborn : statistical visulisation

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
##numerical data plotting  #This function provides access to several different axes-level functions
##that show the relationship between two variables with semantic mappings
##of subsets. The kin-d parameter selects the underlying axes-level
## function to use:
sns.relplot(x= "total_bill" , y = "tip", data  =  df)

# %%
sns.scatterplot(x= df.total_bill , y = df.tip ,data = df , hue = 'smoker') ## by default it gives scatter plot, kind = line gives you line plot
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
## as the bill increase , the tip also increases
## highest tip was paid by a smoker
sns.relplot(x= "total_bill" , y = "tip", data  =  df , hue = 'smoker')

# %%
sns.relplot(x= "total_bill" , y = "tip", data  =  df , hue = 'size')

# %%
sns.relplot(x= "total_bill" , y = "tip", data  =  df ,style = 'smoker', hue = 'time')## hue gives different colour

# %%
sns.relplot(x= "total_bill" , y = "tip", data  =  df ,style = 'size', )

# %%
value  = np.random.randn(100)

# %%
value
# Out:
# array([ 0.71516875,  2.97594375,  0.31816369,  0.06375553, -1.03654344,
#        -1.03703117,  1.18901562,  0.80713705,  0.01440957,  1.33141518,
#        -0.22011302, -1.13937453,  0.15117064,  0.09891284,  0.40609009,
#        -0.96434538, -0.04999126,  1.0534437 , -1.85783884, -1.15199098,
#         0.70697458,  2.20416913, -0.9807685 ,  0.39277164,  0.01605161,
#         0.6397165 , -0.74980084, -1.73198939, -0.10025228,  0.75455562,
#        -0.28665235,  1.49628407,  2.18684706, -0.73799723,  0.67248079,
#        -0.52430416,  0.48364419, -1.54076445,  1.41749761, -0.60523581,
#         0.05568374,  0.3594916 ,  1.87242203, -0.05138471, -0.10227174,
#        -0.27282311,  0.6867623 ,  0.07573556,  0.89039239, -1.16109345,
#         0.37852455, -0.69988937,  0.22316929,  0.36326011, -0.14615832,
#         1.86110576, -0.45356646,  1.28655687,  1.42716491,  0.17047064,
#         0.7567507 , -1.59159619,  0.30986996, -0.56598624,  2.64274123,
# ...

# %%
 # ## relplot to make a line plot  >> generated time series  a data
 time = np.arange(500)
 value = np.random.randn(500).cumsum()
df = pd.DataFrame({'time': time , 'value' : value})

# %%
df
# Out:
#      time      value
# 0       0   0.866829
# 1       1  -0.699710
# 2       2   0.538006
# 3       3   1.638513
# 4       4  -0.166355
# ..    ...        ...
# 495   495  15.630690
# 496   496  15.963677
# 497   497  14.470175
# 498   498  14.038173
# 499   499  14.549832
#
# [500 rows x 2 columns]

# %%
sns.relplot(x ='time',y = 'value' ,kind = 'line',data = df ,sort = True)

# %%
fmri =  sns.load_dataset('fmri')

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x  = 'timepoint' ,y='signal',kind= 'line',data = fmri)

# %%
fmri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %%
sns.relplot(x  = 'timepoint' ,y='signal',kind= 'line',data = fmri,ci = 'sd')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x  = 'timepoint' ,y='signal',estimator = None ,kind= 'line',data = fmri,ci = 'sd')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x  = 'timepoint' ,y='signal',kind= 'line',data = fmri,ci = 'sd' ,hue = 'event')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x  = 'timepoint' ,y='signal',kind= 'line',data = fmri,ci = 'sd' ,hue = 'event' ,style = 'region')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x  = 'timepoint' ,y='signal',kind= 'line',data = fmri,ci = 'sd' ,hue = 'event' ,style = 'region',markers=True,dashes=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x  = 'timepoint' ,y='signal',kind= 'line',data = fmri,ci = 'sd' ,hue = 'event' ,style = 'region')

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill' , y = 'tip',hue = 'smoker',data = tips, col = 'time')

# %%
sns.relplot(x = 'total_bill' , y = 'tip',hue = 'smoker',data = tips, col = 'size')

# %%
sns.scatterplot(x = 'total_bill' ,y = 'tip',data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x = 'day' , y = 'total_bill',data = tips)

# %%
sns.catplot(x = 'day' , y = 'total_bill',data = tips , kind='swarm')

# %%
sns.catplot(x = 'day' , y = 'total_bill',data = tips , kind='box')

# %%
sns.catplot(x = 'day' , y = 'total_bill',data = tips , kind='boxen')

# %%
sns.catplot(x = 'day' , y = 'total_bill',data = tips , kind='violin')

# %%
sns.barplot(x = 'day' , y = 'total_bill' ,data  = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x  = tips.total_bill,y = tips.tip)## raw aplot of two variables with bivaraite and univariate graphs

# %%
sns.jointplot(x  = tips.total_bill,y = tips.tip, kind  = 'reg')

# %%
sns.jointplot(x  = tips.total_bill,y = tips.tip, kind  = 'hex')

# %%
sns.jointplot(x  = tips.total_bill,y = tips.tip, kind  = 'kde') ## kernel density estimation , contour >> metroloigical

# %%
## pairplot >> it will plot all the pair wise relationship between data frames
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue = 'smoker')

# %%
sns.pairplot(tips , hue = 'smoker' ,palette='coolwarm')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
## boxplot

sns.boxplot(x= 'day', y = 'total_bill' ,data = tips,palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## boxplot

sns.boxplot(data = tips,palette='rainbow', orient='h')
# Out:
# <Axes: >

# %%
tips = tips[['total_bill','tip','size']]

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr() ,cmap= 'coolwarm' ,annot=True)
# Out:
# <Axes: >

# %%
tips
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x = 'sex' , data = df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x  = "total_bill" , y = 'tip',data = df)

# %%
sns.lmplot(x  = "total_bill" , y = 'tip',data = df,height=15, aspect = 0.5)
